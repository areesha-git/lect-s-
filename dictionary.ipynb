# %%
dt={}
dt1=dict()
print(dt,dt1)
# Out:
# {} {}

# %%
dt={1:5,"hello":35,3.5:"python",7:2}
print(dt)
# Out:
# {1: 5, 'hello': 35, 3.5: 'python', 7: 2}

# %%
lst=[(2,5),(8,"hello"),(9,7.5),(8,5)]
d=dict(lst)
print(d)
# Out:
# {2: 5, 8: 5, 9: 7.5}

# %%
d6=dict(({'Mango',50},{'Orange',80}))
print(d6)
# Out:
# {50: 'Mango', 80: 'Orange'}

# %%
dt={1:23,45:2,'hello':5.6,'hii':55}
print(dt['hello'])
# Out:
# 5.6

# %%
print(dt.key())
print(dt.values())
print(dt.items())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(dt.key())
#       2 print(dt.values())
#       3 print(dt.items())
#
# NameError: name 'dt' is not defined
