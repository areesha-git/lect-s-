# %%
print("hello global")
# Out:
# hello global

# %%
print("bye")
# Out:
# bye

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
y=9
print(id(x),id(y),id(z))
# Out:
# 140732857275640 140732857275704 140732857275640
# 140732857275640 140732857275768 140732857275640

# %%
name=input("Enter your name")
print(name)
age=int(input("Enter your age"))
print(type(age))
height=float(input("Enter your height"))
print("My name is",name,"and my age is ",age,"and height is",height)
# Out:
# areesha
# <class 'int'>
# My name is areesha and my age is  19 and height is 5.4

# %%
# write a program take len width as a input calculate area of that rectangle
length=int(input("Enter your length"))
width=int(input("Enter your width"))
area = length*width
print("area of rectangle is",area)
# Out:
# 25

# %%
#write a program which will take degree calciuse as input and print fahrenheit
degree= int(input("enter degree in calciuse"))
fahrenheit= (degree*9/5)+32
print("degree in fahrenheit is",fahrenheit)
