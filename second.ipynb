# %%
#write a program which will take degree calciuse as input and print fahrenheit
degree= int(input("enter degree in calciuse"))
fahrenheit= (degree*9/5)+32
print("degree in fahrenheit is",fahrenheit)

# %%
lst =[[1,2,4,5],[3,5,4,3],[4,5,3,2]]
lst1=[sum(i) for i in lst]
print(lst1)
# Out:
# [12, 15, 14]

# %%
for i in range(1,51,1):
 if i%3==0 and i%5==0:
    print("FizzBuzz")
 elif i%3==0:
    print("Fizz")    
 elif i%5==0:
    print("Buzz")  
 
 else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz

# %%
# W.A.P which will take a number as input as a factor
number = int(input("Enter a number:"))
for i in range(1 , number+1):
    if number%i==0:
        print(i, end=" ")
# Out:
# 1 2 3 4 6 12

# %%
# factorial
number= int(input("Enter a number"))
factorial = 1
for i in range(number,0,-1):
    factorial = factorial * i
    
print("the factorial of",number ,"is",factorial)
# Out:
# the factorial of 5 is 120

# %%
number = int(input("Enter a number:"))
counteven = 0
countodd = 0
for i in range(1 , number+1):
    if number%i==0:
            if i%2==0:
             counteven = counteven + 1
            elif i%2!=0: 
              countodd = countodd + 1  
print("counteven",counteven)
print("countodd",countodd)
# Out:
# counteven 4
# countodd 2

# %%
number = int(input("Enter your number"))
if_prime =0
for i in range(2, number):
    if number%i==0:
        if_prime = if_prime + 1
if if_prime == 0:
        print(number,"is a prime number")   
else :
        print (number,"is not a prime number")
# Out:
# 6 is not a prime number

# %%
# W.A.P 
num  = int(input("Enter number")) 
count = 0 
while num!=0 : 
    count = count + 1
number=int (input("Enter your number"))
count=0
i=number
while i!=0 :
    count=count+1
    i=i%10
print(count)

# %%
# W.A.P which will take a num as a input from the user if a number is even it will calculate the factorial and if the odd then calculate its factorial
# num = int(input("Enter a number"))
# for i in range(1,num+1) :
#     if n%i==0:
#         print(Even)

def factorial(num):
    fact=1
    for i in range (num,0,-2):
        if num%2==0 :
            fact *=i 
        elif num%2!=0 :
             fact *=i 
    print(fact)

factorial(12)
factorial(13)
# Out:
# 46080
# 135135

# %%
# W.A.P which will take input from user and calculate ncr
