# %%
s=set()
print(s)
s1={}
print(type(s1))
# Out:
# set()
# <class 'dict'>

# %%
s={1,2,3,"hello"}
print(s)
# Out:
# {1, 2, 3, 'hello'}

# %%
lst=[1,2,3,4,2,3,43,4]
lst=list(set(lst))
print(lst)
# Out:
# [1, 2, 3, 4, 43]

# %%
s={1,2}
# s.add((1,2,3,4,5))
s.update((4,6,1,9,5))
print(s)
# Out:
# {1, 2, 4, 5, 6, 9}

# %%
s={1,2,4,5,6}
print(s)
s.discard(4)
print(s)
# Out:
# {1, 2, 4, 5, 6}
# {1, 2, 5, 6}

# %%
s={1,2,4,5,6}
print(s)
a=s.pop()
print(a)
print(s)
# Out:
# {1, 2, 4, 5, 6}
# 1
# {2, 4, 5, 6}
