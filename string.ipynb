# %%
x="hello everyone"
print(x)
# Out:
# hello everyone

# %%
print(x[ : :-10])
print(x[-10:-1:5])
print(x[-10:-1:5])
print(x[-10:-1:5])
print(x[-10:-1:5])
# Out:
# n o
# ll
# ll
# ll
# ll

# %%
x ="python tu'torials"
print(x[-3:-8:-1])
print(x[-2:4:-1])
# Out:
# airot
# lairot'ut n

# %%
x = "hello"
for i in x:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
str= "hello user i , am - learning python"
lst=str.split()
lst1=str.split(sep=",")
print(lst,lst1)
# Out:
# ['hello', 'user', 'i', ',', 'am', '-', 'learning', 'python'] ['hello user i ', ' am - learning python']

# %%
word_list=['hello','user','i','am',
            'learning','python']
temp="#".join(word_list)
print(temp)
# Out:
# hello user i am learning python

# %%
text="apple banana apple cherry apple"
modified_text = text.replace("apple","orange")
print(text)
print(modified_text)
# Out:
# apple banana apple cherry apple
# orange banana orange cherry orange

# %%
text='Global college # 1'
text1=sorted(text)
print(text)
a=''.join(text1)
print(text)
print(a)
# Out:
# Global college # 1
# Global college # 1
#    #1Gabceeglllloo

# %%
x ="hello,everyone.lets,learn,python."
x=x.replace(".","$")
x=x.replace(",",".")
x=x.replace('$',",")
print(x)
# Out:
# hello.everyone,lets.learn.python,
