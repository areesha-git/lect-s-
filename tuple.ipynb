# %%
x=1,
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 x=1,
# ----> 2 print(type(x))
#
# TypeError: 'int' object is not callable

# %%
tpl=(1,2,3,4,5)
print(type(tpl),tpl)
# Out:
# <class 'tuple'> (1, 2, 3, 4, 5)

# %%
x = (5,)
print(type(x))
# Out:
# <class 'tuple'>

# %%
tpl = (4,5,6,7)
print(tpl[2])
print(tpl[2:])
print(tpl[-1])
# Out:
# 6
# (6, 7)
# 7

# %%
tpl = (4,5,6,7,45,67,[3,4,5])
tpl[-1][1]=40
print(tpl)
# Out:
# (4, 5, 6, 7, 45, 67, [3, 40, 5])

# %%
tpl=(1,2,3,4,3,3,5,7)
tpl.count(3)
# Out:
# 3

# %%
tpl
